# %%
h=int(input())
A=input().split()[:h]
A=list(A)
b=list(map(float,A))
c=min(b)*2
print('{:.2f}'.format(c))
# Out:
# 3
# 1 5 6
# 2.00

# %%
n=int(input())
a1,b1=input().split()[:n]
a2,b2=input().split()[:n]
a3,b3=input().split()[:n]
if float(b1)<50:
  print(float(a1))
elif float(b1)<50 and float(b2)<50:
  print(int(a1)+int(a2))
elif float(b1)<50 and float(b2)<50 and float(b3)<50:
  print(int(a1)+int(a2)+int(a3))
elif float(b2)<50 and float(b3)<50:
  print(int(a2)+int(a3))
elif float(b1)<50 and float(b3)<50:
  print(int(a1)+int(a3))
# Out:
# 3
# 2 100.00
# 5 23.00
# 100  22.50
# 100.0

# %%
a,b,c,d=input().split()
if float(a)>0 and float(b)>0 and float(c)>0 and float(d)>0:
  if float(a)==float(c) and float(b)==float(d):
    print("YES")
  else:
    print("NO")
else:
  print("NO")

# %%
a=input()
a=list(a)
d=list(map(int,a))
b=d[0]
if b>0:
 e=sum(d)
 print(e)

# %%
n=int(input())
a=input().split()[:n]
a=list(a)
a=list(map(int,a))
b=sum(a)
c=b/n
print(c)
# Out:
# 3
# 1 2 3
# 2.0

# %%
a=input()
a=list(a)
a=a[0]+a[1]+a[2]
print(a[2]+a[1]+a[0])
# Out:
# 123
# 321

# %%
a=input()
a=list(a)
a=a[0]+a[1]+a[2]+a[3]
print(a[0]+a[2]+a[1]+a[3])
# Out:
# 1234
# 1324

# %%
a==1
a+1==2
n=int(input())
if n/2==n//2:
  print(n//2)
else:
  print((n//2)+1)
# Out:
# 3
# 2

# %%
a,b=input().split()
c=int(a)+int(b)
print(a,"+",b,"=",c)
# Out:
# 4 5
# 4 + 5 = 9

# %%
a=input()
a=list(a)
print(a[-1])
# Out:
# this is my home
# e

# %%
a=input()
a=a[0]+a[1]+a[2]
c=list(sorted(a))
x=''.join(c)
d=list(reversed(c))
y=''.join(d)
print((int(y)-int(x))**2)
# Out:
# 352
# 88209

# %%
N=input()
N=list(N)
N=list(map(int,N))
N=list(filter(lambda x: x!=2 and x!=7,N))
print(''.join(list(map(str,N))))
# Out:
# 527012
# 501

# %%
N=input()
N=list(N)
a=list(reversed(N))
m=list(map(int,a))
n=list(map(int,N))
n=''.join(N)
m=''.join(a)
print(int(n)+int(m))
# Out:
# 34267
# 110510

# %%
N=input().split()
N=list(N)
N=list(map(int,N))
a=list(filter(lambda x:x<0 ,N))
print(len(a))
# Out:
# 5 4 5 -1 -206
# 2

# %%
n,m=input().split()
a=list(filter(lambda x: x/1 and x/x,N))

# %%
a=int(input())
a=list(a)
a=a[0]+a[1]+a[2]
b=list(map(int,a))
c=a[2]

# %%
a,b,c=input().split()
if int(a)<=1000 and int(b)<=1000 and int(c)<=1000:
  if int(a)!=int(b) and int(b)!=int(c) and int(a)!=int(c):
    print((int(a)+int(b)+int(c))//3)
# Out:
# 15 4 6
# 8

# %%
x,y,z=input().split()
x=float(x)
y=float(y)
z=float(z)
a=x+y
b=x+z
c=y+z
print('{:.4f}'.format(a),'{:.4f}'.format(b),'{:.4f}'.format(c))
# Out:
# 2 3 4
# 5.0000 6.0000 7.0000

# %%
n=input()
n=list(n)
n=n[0]+n[1]
a=list(map(int,n))
b=int(n[0])+int(a[1])
c=int(n[0])*int(n[1])
print(b,c)
# Out:
# 46
# 10 24

# %%
n=input()
n=list(n)
n=n[0]+n[1]
a=list(map(int,n))
b=n[1]+n[0]
print(b)
# Out:
# 46
# 64

# %%
a=input().split()
a=list(a)
x=a[0]+a[1]+a[2]+a[3]
e=list(map(float,a))
b=float(a[0])+float(a[1])
c=b+float(a[2])
d=c+float(a[3])
print(b)
print(c)
print(d)
# Out:
# 1 2 3 4
# 3.0
# 6.0
# 10.0

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]
c=list(map(int,a))
print((int(a[0])**2)+(int(a[1])**2)+(int(a[2])**2)+(int(a[3])**2))
# Out:
# 1234
# 30

# %%
x=int(input())
if x>0:
  print('1')
elif x==0:
  print('0')
else:
  print('-1')
# Out:
# -23
# -1

# %%
t=int(input())
if t>0:
  print('Water')
else:
  print('Ice')
# Out:
# -6
# Ice

# %%
x=int(input())
if x>=0:
  y=(x**3)+((x**2)*2)+(4*x)-6
  print(y)
else:
  y=(x**3)-(7*x)
  print(y)
# Out:
# -2
# 6

# %%
x=int(input())
if x>=13:
  print(((x**3)*3)+((x**2)*4)+(x*5)+6)
else:
  print(((x**3)*3)-((x**2)*2)-(3*x)-4)
# Out:
# -11
# -4206

# %%
x,a,b=input().split()
x=int(x)
a=int(a)
b=int(b)
if a<=x and x<=b:
  print('YES')
else:
  print('NO')
# Out:
# 5 10 15
# NO

# %%
x,a,b=input().split()
x=int(x)
a=int(a)
b=int(b)
if x<a or x>b:
  print('OUT')
else:
  print('IN')
# Out:
# -5 1 1
# OUT

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]
c=list(map(int,a))
if int(a[1])==0:
  print(int(a[2]))
else:
  print(a[1]+a[2])
# Out:
# 1234
# 23

# %%
a=input()
a=list(a)
b=a[0]+a[1]
c=list(map(int,a))
print(int(a[0])+int(a[1]))
# Out:
# 37
# 10

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]
if a[0]=='-':
  a.append(a[3])
  print(a[1])
  print(a[2])
  print(a[3])
else:
  print(a[0])
  print(a[1])
  print(a[2])
# Out:
# 123
# 1
# 2
# 3

# %%
a=input()
a=list(a)
b=list(map(int,a))
print(int(a[-1]))
# Out:
# 123
# 3

# %%
a,b=input().split()
c=int(a)//int(b)
d=int(a)%int(b)
print(c,d)
# Out:
# 27 10
# 2 7

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]
print(a[0],a[1],a[2])
# Out:
# 123
# 1 2 3

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]
print('3'+b+'3')
# Out:
# 123
# 31233

# %%
a,b,c=input().split()
a=int(a)
b=int(b)
c=int(c)
print((a*7+b-2)*(a-c+5))
# Out:
# 1 2 3
# 21

# %%
x=int(input())
if x<5:
  print((x**2)-(3*x)+4)
else:
  print(x+7)
# Out:
# 10
# 17

# %%
x=int(input())
if x>=10:
  print((x**3)+(5*x))
else:
  print((x**2)-(2*x)+4)
# Out:
# 20
# 8100

# %%
x=int(input())
if x<-4:
  print(x+5)
elif x>=-4 and x<=7:
  print((x**2)-(3*x))
else:
  print((x**3)+(2*x))
# Out:
# -8
# -3

# %%
a,b,c=input().split()
if int(a)/2==int(a)//2 or int(b)/2==int(b)//2 or int(c)/2==int(c)//2:
  if int(a)/2!=int(a)//2 or int(b)/2!=int(b)//2 or int(c)/2!=int(c)//2:
    print("YES")
  else:
    print("NO")
else:
  print("NO")
# Out:
# 4 4 4
# NO

# %%
h,w,l,k=input().split()
h=int(h)
w=int(w)
l=int(l)
k=int(k)
if h!=0 and w!=0 and l!=0:
  a=(h*w*l)/k
  b=a%1
  if b>=0:
    if b==0:
      print(round(a))
    else:
      c=(h*w*l)//k
      print(c+1)
# Out:
# 2 3 4 1
# 24

# %%
a=input()
if int(a)>0:
  a=list(a)
  b=a[0]+a[1]
  print(int(a[0])+int(a[1]))
else:
  a=list(a)
  b=a[0]+a[1]+a[2]
  print(int(a[1])+int(a[2]))
# Out:
# -23
# 5

# %%
a=input()
if int(a)>0:
  a=list(a)
  b=a[0]+a[1]+a[2]
  print((int(a[0])*int(a[1])*int(a[2]))-(int(a[0])+int(a[1])+int(a[2])))
else:
  a=list(a)
  b=a[0]+a[1]+a[2]+a[3]
  print((int(a[1])*int(a[2])*int(a[3]))-(int(a[1])+int(a[2])+int(a[3])))

# %%
m,n,k=input().split()
m=int(m)
n=int(n)
k=int(k)
if m/k==m//k and n/k==n//k:
  a=(m//k)+(n//k)
  print(a)
elif m/k==m//k and not n/k==n//k:
  a=m//k
  b=n//k
  c=b+1
  print(a+c)
elif n/k==n//k and not m/k==m//k:
  a=m//k
  b=n//k
  c=a+1
  print(a+c)
else:
  a=n//k
  b=m//k
  c=a+1
  d=b+1
  print(c+d)
# Out:
# 5 22 3
# 10

# %%
n,m=input().split()
n=int(n)
m=int(m)
if m/n==m//n:
  print('1')
else:
  a=m//n
  print(a+1)
# Out:
# 2 3
# 2

# %%
n=int(input())
if ((n%2==0) or ((n<0) and (n%3==0)))and not (n%2==0 and n<0 and n%3==0):
  print("YES")
else:
  print("NO")
# Out:
# -3
# YES

# %%
n=int(input())
if n%2==1 or (n>=100 and n<=999):
  print("YES")
else:
  print("NO")
# Out:
# 54563
# YES

# %%
n=int(input())
if n%3==0 and n%2==0 and ((n>9 and n<100) or (n<-9 and n>-100)):
  print('YES')
else:
  print('NO')
# Out:
# 27
# NO

# %%
n=int(input())
if not (n%2==0 and n>0) and not (n%2==1 and n<0):
  print("YES")
else:
  print("NO")
# Out:
# 24
# NO

# %%
a,b,c=input().split()
a=int(a)
b=int(b)
c=int(c)
if (a>0 or b>0 or c>0) and (a<0 or b<0 or c<0):
  print("YES")
else:
  print("NO")
# Out:
# 444 445 44
# NO

# %%
a=input()
if int(a)>99 and int(a)<1000:
  a=list(a) 
  b=a[0]+a[1]+a[2]
  if a[0]!=a[1] and a[1]!=a[2] and a[0]!=a[2]:
    print('YES')
  else:
    print('NO')
elif int(a)>-1000 and int(a)<-99:
   a=list(a)
   b=a[0]+a[1]+a[2]+a[3] 
   if a[3]!=a[1] and a[1]!=a[2] and a[3]!=a[2]:
      print('YES')
   else:
      print('NO')
# Out:
# 456
# YES

# %%
n=int(input())
if n%2==0:
  print("EVEN")
else:
  print("ODD")
# Out:
# 100
# EVEN

# %%
a=int(input())
if a%2==0:
  print(a+1)
else:
  print(a+2)
# Out:
# 8
# 7

# %%
a=int(input())
if a%2==1:
  print(a+1)
else:
  print(a+2)
# Out:
# 7
# 9

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]
c=a[3]+a[2]+a[1]+a[0]
if b==c:
  print("YES")
else:
  print('NO')
# Out:
# 5446
# NO

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]+a[4]
if a[0]<a[1] and a[1]<a[2] and a[2]<a[3] and a[3]<a[4]:
  print('YES')
else:
  print('NO')
# Out:
# 15568
# NO

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]
if a[0]==a[1] and a[1]==a[2] and a[2]!=a[3]:
  print('YES')
elif a[0]==a[1] and a[1]!=a[2] and a[1]==a[3]:
  print('YES')
elif a[0]!=a[1] and a[2]==a[3] and a[0]==a[3]:
  print('YES')
elif a[0]!=a[1] and a[2]==a[3] and a[1]==a[3]:
  print('YES')
else:
  print('NO')
# Out:
# 9777
# YES

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]
if a[0]==a[1] and a[1]!=a[2] and a[2]==a[3]:
  print('YES')
elif a[0]==a[1] and a[1]!=a[2] and a[2]==a[3]:
  print('YES')
elif a[0]!=a[1] and a[1]==a[3] and a[0]==a[2]:
  print('YES')
elif a[0]!=a[1] and a[2]==a[0] and a[1]==a[3]:
  print('YES')
elif a[0]!=a[1] and a[2]==a[1] and a[0]==a[3]:
  print('YES')
else:
  print('NO')
# Out:
# 2224
# NO

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]
if int(a[0])>0:
  if (int(a[0])==3 and int(a[1])==7) or (int(a[0])==7 and int(a[1])==3) or (int(a[1])==3 and int(a[2])==7) or (int(a[1])==7 and int(a[2])==3) or (int(a[2])==7 and int(a[3])==3) or (int(a[2])==3 and int(a[3])==7):
    print('YES')
  else:
    print('NO')
# Out:
# 4545
# NO

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]
a[0]=int(a[0])
a[1]=int(a[1])
a[2]=int(a[2])
a[3]=int(a[3])
if a[0]%2==0 and a[1]%2==0 and a[2]%2==0 and a[3]%2==0:
  print('YES')
else:
  print('NO')
# Out:
# 4286
# YES

# %%
a=input()
a=list(a)
b=a[0]+a[1]+a[2]+a[3]
a[0]=int(a[0])
a[1]=int(a[1])
a[2]=int(a[2])
a[3]=int(a[3])
if a[0]%2==1 or a[1]%2==1 or a[2]%2==1 or a[3]%2==1:
  print('YES')
else:
  print('NO')
# Out:
# 4447
# YES

# %%
a=input()
a=list(a)
b=sorted(a)
print(b.count(b[-1]))
# Out:
# 886876876
# 4

# %%
n=input()
l=len(n)
if l==1:
  print('Ok')
else:
  print('No')

# %%
a,b,c,d=input().split()
a=int(a)
b=int(b)
c=int(c)
d=int(d)
if a==b and b==c and c==d:
  print(a**2)
else:
  print('No')
# Out:
# 7 7 7 6
# No

# %%
a,b,c,x,y=input().split()
a=int(a)
b=int(b)
c=int(c)
x=int(x)
y=int(y)
if (b<x or a<x or c<y) or (c<x or a<x or b<y) or (b<x or c<x or a<y) or (b<y or a<y or c<x) or (c<y or a<y or b<x) or (b<y or c<y or a<x) or ((a*b*c)<(x*y)):
  print('YES')
else:
  print('NO')

# %%
import math
x,y=input().split()
x=float(x)
y=float(y)
print('{:.3f}'.format((((x-y)**2)/(math.sqrt((x**2)+(y**2)-1)))+((math.sqrt((x**2)+(y**2)-1))/(2*x*y))))
# Out:
# 1.000 -2.000
# 4.000

# %%
x,y=input().split()
x=float(x)
y=float(y)
print('{:.3f}'.format((((x**2)-(2*x*y)+(4*(y**2)))/(x+5))+((3*(x**2))-(y**2))/(y-7)))
# Out:
# 1.000 -2.000
# 3.611

# %%
x,y=input().split()
x=float(x)
y=float(y)
print('{:.3f}'.format((((2*x)+y)/((x*2)-(x*y)+(4*(y**2))))+(((2*(x**2))-(x*y)+(y**2))/(x+(4*y)))))
# Out:
# 1.000 -2.000
# -1.143

# %%
import math
x,y=input().split()
x=float(x)
y=float(y)
z=((2*x*y)/(math.sqrt((x**2)+(y**2))))-(((x+y-1)**2)/(x*y))
print('{:.3f}'.format(z))
# Out:
# 1.000 -2.000
# 0.211

# %%
import math
x,y=input().split()
x=float(x)
y=float(y)
z=(math.sqrt((x**2)+(y**2))/((x-y)**2))-((2*x*y)/(math.sqrt((x**2)+(y**2))))
print('{:.3f}'.format(z))
# Out:
# 1.000 -2.000
# 2.037

# %%
m,n=input().split()
m=int(m)
n=int(n)
print(m//n)
# Out:
# 27 10
# 2

# %%
m,n=input().split()
m=int(m)
n=int(n)
print(m%n)
# Out:
# 27 10
# 7

# %%
n=input()
n=list(n)
del n[-3]
print(''.join(n))
# Out:
# 512
# 51

# %%
a=input()
d=int(a)//100
b=(int(a)%100)//10
c=int(a)%10
b=str(b)
c=str(c)
print(str(d)+c+b)
# Out:
# 512
# 521

# %%
a=input()
a=int(a)
d=a//100
b=(a//10)%10
c=a%10
b=str(b)
c=str(c)
d=str(d)
print(c+b+d)
# Out:
# 334
# 433

# %%
a,b,c=input().split()
a=int(a)
b=int(b)
c=int(c)
if a!=0:
  if (b**2)-(4*a*c)==0:
    x=(-b)/(2*a)
    print("One root:",int(x))
  elif(b**2)-(4*a*c)>0:
    d=(b**2)-(4*a*c)
    x1=(-b+d)/(2*a)
    x2=(-b-d)/(2*a)
    if x1>x2:
      print("Two roots:",int(x2),int(x1))
    else:
      print("Two roots:",int(x1),int(x2))
  else:
    print("No roots")
# Out:
# 1 6 4
# Two roots: -13 7

# %%
n=int(input())
print(n*'#')
# Out:
# 7
# #######

# %%
n=input()
m=list(n)
a=list(reversed(m))
print(*a,sep="\n")
# Out:
# 123
# 3
# 2
# 1

# %%
import math
x=int(input())
y=x-(((x**2)+4)/2)+(x**3)-(3/(x+7))
print('{:.3f}'.format(y))
# Out:
# 1
# -0.875

# %%
h1,m1,s1=input().split()
h1=int(h1)
m1=int(m1)
s1=int(s1)
h2,m2,s2=input().split()
h2=int(h2)
m2=int(m2)
s2=int(s2)
h=h2-h1
m=m2-m1
s=s2-s1
if h>=0 and m>=0 and s>=0:
  print(h,m,s)
elif h>00 and m<0 and s>=0:
  print(h-1,((m2+60)-m1),s)
elif h>=0 and m>=0 and s<0:
  print(h,m-1,((s2+60)-s1))
# Out:
# 9 30 0
# 12 45 30
# 3 15 30

# %%
import random
a=random.randint(0 , 1)
if a==0:
  print('Getmə')
else:
  print('Get')
# Out:
# Get

# %%
A=int(input())
B=int(input())
if A>B:
  print('>')
elif A<B:
  print('<')
else:
  print('=')

# %%
x=float(input())
y=((x**2)+(3*x)-4)/(((2*x)-3))-((x+2)/((x**2)-(5*x)+7))
print('{:.3f}'.format(y))
# Out:
# 1
# -1.000

# %%
n=int(input())
a=input().split()[:n]
a=list(a)
b=list(reversed(a))
b=' '.join(b)
print(b)
# Out:
# 7
# 1 2 5 3 7 4 6
# 6 4 7 3 5 2 1

# %%
def GCD(x,y):
  r=x%y
  if r==0:
    return y
  else:
    return GCD(y,r)
n,m=input().split()
n=int(n)
m=int(m)
print(GCD(m,n))
# Out:
# 42 24
# 6

# %%
import math
a,b,c,d,f=input().split()
a=int(a)
b=int(b)
c=int(c)
d=int(d)
f=int(f)
p1=((d+f+c)/2)
p2=((a+b+f)/2)
S1=math.sqrt((p1*(p1-d)*(p1-c)*(p1-f)))
S2=math.sqrt((p2*(p2-a)*(p2-b)*(p2-f)))
S=S1+S2
print('{:.4f}'.format(S))
# Out:
# 3 4 4 2 5
# 9.7997

# %%
n=int(input())
a=input().split()[:n]
a=list(a)
if n>1 and n<=100:
  c=a[0]
  b=a[-1]
  del a[0]
  del a[-1]
  a=' '.join(a)
  print(b,c,a)
# Out:
# 5
# -1 5 4 -6 1
# 1 -1 5 4 -6

# %%
a=input()
a=list(a)
b=' '.join(a)
print(b)
# Out:
# 54
# 5 4

# %%
import math
n=int(input())
P=3*n
S=(math.sqrt(3)*(n**2))/4
print('{:.4f}'.format(P),'{:.4f}'.format(S))
# Out:
# 3
# 9.0000 3.8971

# %%
import math
n=int(input())
a=math.sqrt(n)
print('{:.6f}'.format(a))
# Out:
# 10
# 3.162278

# %%
n=int(input())
if n%3==0:
  print('YES')
else:
  print('NO')
# Out:
# 1234567890987654321
# YES

# %%
a,b,c=input().split()
a=int(a)
b=int(b)
c=int(c)
if ((a**2)+(b**2)==(c**2)) or ((a**2)+(c**2)==(b**2)) or ((c**2)+(b**2)==(a**2)):
  print("YES")
else:
  print("NO")
# Out:
# 3 5 5
# NO

# %%
x,y=input().split()
x=float(x)
y=float(y)
y=x/y
print('{:.0f}'.format(y))
# Out:
# 6.3 0.7
# 9

# %%
a=input()
a=list(a)
del a[0]
b=a.count('-')
c=a.count('+')
d=a.count('*')
print(b+c+d)
# Out:
# -1+2*3+a
# 3

# %%
x,y=input().split()
x=float(x)
y=float(y)
if x>0 and y>0:
  print('1')
elif x<0 and y>0:
  print('2')
elif x<0 and y<0:
  print('3')
elif x>0 and y<0:
  print('4')
else:
  print('0')
# Out:
# 12.5 30.0
# 1

# %%
n=int(input())
a=input().split()[:n]
a=list(a)
a=list(map(float,a))
a=list(map(lambda a:abs(a),a))
print('{:.2f}'.format(max(a)))
# Out:
# 4
# -76.45 7.5 -5.1 75.23
# 76.45

# %%
n=input()
n=list(n)
a=int(input())
print(n.count(str(a)))
# Out:
# -2555
# 5
# 3

# %%
a=input()
b=list(a)
c=list(reversed(b))
d=''.join(c)
a=int(a)
if a==int(d):
  print('Yes')
else:
  print('No')
# Out:
# 10
# No

# %%
a=input()
if int(a)<0:
  a=list(a)
  del a[0]
  b=list(map(int,a))
  print(sum(b))
else:
  a=list(a)
  b=list(map(int,a))
  print(sum(b))
# Out:
# 156
# 12

# %%
m,n,k=input().split()
m=int(m)
n=int(n)
k=int(k)
a=m/n
print('{:.str(k')

# %%
a=int(input())
b=bin(a)
b=list(b)
print(b.count('1'))
# Out:
# 7
# 3

# %%
a=str(input())
print(int(a,2))
# Out:
# 100
# 4

# %%
n=int(input())
a=bin(n)
a=list(a)
del a[0]
b=a.remove('b')
c=list(reversed(a))
d=c.remove('1')
x=c.insert(0,'0')
e=list(reversed(c))
f=''.join(e)
print(int(f,2))
# Out:
# 4
# 0

# %%
n=input()
if int(n)>=100 and int(n)<=999:
  n=list(n)
  b=n[0]+n[1]+n[2]
  c=n[2]+n[1]+n[0]
  d=''.join(c)
  print(d)
# Out:
# 456
# 654

# %%
n=int(input())
if n>=100 and n<=999:
  a=n//100
  b=n%10
  c=(n-b)+a
  d=(((n-(a*100))+(b*100))-b)+a
  print(d)
# Out:
# 198
# 891

# %%
x1,y1,x2,y2,x3,y3,x4,y4=input().split()
x1=int(x1)
y1=int(y1)
x2=int(x2)
y2=int(y2)
x3=int(x3)
y3=int(y3)
x4=int(x4)
y4=int(y4)

# %%
a,b=input().split()
a=str(a)
b=str(b)
print(b,a)
# Out:
# İlahə Alqayeva
# Alqayeva İlahə

# %%
a=str(input())
b=a.split()
print(len(b))
# Out:
# i am 15 years old.
# 5

# %%
a=str(input())
a=a.capitalize()
if a=='Hi' or a=='Hello':
  print('Hi,i am Alex.I created by Ilaha to help you about few things.How are you?')
  a=str(input())
  if a=='I am great':
    print('How can i help you then?')
    a=str(input())
    if a=="Tell me joke" or a=='Tell me jokes':
      print('Why did the gym closed down?')
      a=str(input(''))
      print('Because it did not worked out.')
      print('HA HA HA')
      a=int(input('If you want hear more press 1 else press 0:'))
      if a==0:
        print('Bye')
      else:
        print('How do actors stay cool?')
        print('They have a lot of fans.')
        print('HA HA HA')
    elif a=="How can i write 'Hello World' in python?":
      print('print("Hello World")')
  elif a=='I am bored':
    print('How can i entertain you?')
    a=str(input())
    if a=="Tell me joke":
      print('Why did the gym closed down?')
      a=str(input(''))
      print('Because it did not worked out.')
      print('HA HA HA')
      a=int(input('If you want hear more press 1 else press 0:'))
      if a==0:
        print('Bye')
      else:
        print('How do actors stay cool?')
        print('They have a lot of fans.')
        print('HA HA HA')
    elif a=="How can i write 'Hello World' in python?":
      print('print("Hello World")')
  elif a=='I am sad':
    print('How can i cheer you up?')
    a=str(input())
    if a=="Tell me joke":
      print('Why did the gym closed down?')
      a=str(input(''))
      print('Because it did not worked out.')
      print('HA HA HA')
      a=int(input('If you want hear more press 1 else press 0:'))
      if a==0:
        print('Bye')
      else:
        print('How do actors stay cool?')
        print('They have a lot of fans.')
        print('HA HA HA')
    elif a=="How can i write 'Hello World' in python?":
      print('print("Hello World")')
      a=str(input())
      print('bye')
  else:
    print('Bye then.')
# Out:
# hi
# Hi,i am Alex.I created by Ilaha to help you about few things.How are you?
# I am bored
# How can i entertain you?
# Tell me joke
# Why did the gym closed down?
# I really don't know
# Because it did not worked out.
# HA HA HA
# If you want hear more press 1 else press 0:1
# How do actors stay cool?
# They have a lot of fans.
# HA HA HA

# %%
n=int(input())
a=(n//100)%10 
b=n%10 
c=((n-(a*100))+(b*100))-b+a
print(c)
# Out:
# 4565
# 4565

# %%
x,y=input().split()
x=float(x)
y=float(y)
print('{:.3f}'.format((((2*x)+y)/((x**2)-(x*y)+(4*(y**2))))+(((2*(x**2))-(x*y)+(y**2))/(x+(4*y)))))
# Out:
# 1.000 -2.000
# -1.143

# %%
n=int(input())
a=(n//100)%10
b=(n//10)%10
c=((n-(a*100))+(b*100))-(b*10)+(a*10)
print(c)
# Out:
# 1234
# 1324

# %%
a=int(input())
if int(str((a//1000)%10)+str((a//100)%10))==37 or int(str((a//100)%10)+str((a//10)%10))==37 or int(str((a//10)%10)+str(a%10))==37:
  print('YES')
else:
  print('NO')
# Out:
# 1730
# NO

# %%
n=int(input())
a=input().split()[:n]
a=list(map(int,a))
for i in range(len(a)):
  print(a[i-1],end=' ')
# Out:
# 4
# 1 2 3 4
# 4 1 2 3

# %%
a=str(input())
b=a.split()
print(len(b)-b.count('!')-b.count(',')-b.count('.')-b.count('?')-b.count(':'))
# Out:
# salam menim adim ilahedir. menim 15 yasim var
# 8

# %%
a,b=input().split()
a=int(a)
b=int(b)
if a/b==a//b:
  print('Divisible')
else:
  print((a//b),(a%b))
# Out:
# 15 5
# Divisible

# %%
n,a,b=input().split()
n=int(n)
a=int(a)
b=int(b)
if n/a==n//a and n/b==n//b:
  print('YES')
else:
  print('NO')
# Out:
# 12 4 6
# YES

# %%
a,b,c=input().split()
a=int(a)
b=str(b)
c=int(c)
if b=='+':
  print(a+c)
elif b=='-':
  print(a-c)
elif b=='/':
  print(a//c)
else:
  print(a*c)
# Out:
# 19 / 7
# 2

# %%
n=input()
eval(n)
# Out:
# 45 +6
# 51

# %%
a=input()
a=list(a)
b=list(sorted(a))
c=list(reversed(b))
d=list(map(int,b))
e=list(map(int,c))
b=''.join(b)
c=''.join(c)
print((int(c)-int(b))**2)
# Out:
# 352
# 88209

# %%
n=int(input())
for i in range(n):
  print(i+1,"OK")
# Out:
# 3
# 1 OK
# 2 OK
# 3 OK

# %%
a=int(input())
for i in range(a):
  print("*"*(i+1))
# Out:
# 4
# *
# **
# ***
# ****

# %%
a=input()
a=list(a)
print(a.count('5'))
# Out:
# 45654
# 2

# %%
n=str(input())
k=int(input())
a=n*k
print(int(a)**2)
# Out:
# 12
# 3
# 14692348944

# %%
a,b,c=input().split()
a=int(a)
b=int(b)
c=int(c)
if a>b and a>c:
  if b>c:
    print(b)
  else:
    print(c)
elif b>a and b>c:
  if c>a:
    print(c)
  else:
    print(c)
else:
  if a>b:
    print(a)
  else:
    print(b)
# Out:
# 5 6 6
# 6

# %%
a=input()
b=(int(a)//1000)%10
c=(int(a)//100)%10
d=(int(a)//10)%10
e=int(a)%10
f=list(a)
if f.count('0')==0:
  l=list(map(int,a))
  if int(a)//b==int(a)/b and int(a)//c==int(a)/c and int(a)//d==int(a)/d and int(a)//e==int(a)/e:
    print('YES')
  else:
    print('NO')
else:
  print('NO')
# Out:
# 2000
# NO

# %%
n=int(input())
for i in range(n):
  if i>0:
    if (i**2)<n:
      print(i**2,end=' ')
# Out:
# 1
